# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelBinarizer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC

# %% [markdown]
# # 1. Load data

# %%
df = pd.read_csv("data/svm/raisins.csv")
df.head()
# Out:
#     Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0  87524       442.246011       253.291155      0.819738       90546
# 1  75166       406.690687       243.032436      0.801805       78789
# 2  90856       442.267048       266.328318      0.798354       93717
# 3  45928       286.540559       208.760042      0.684989       47336
# 4  79408       352.190770       290.827533      0.564011       81463
#
#      Extent  Perimeter    Class
# 0  0.758651   1184.040  Kecimen
# 1  0.684130   1121.786  Kecimen
# 2  0.637613   1208.575  Kecimen
# 3  0.699599    844.162  Kecimen
# 4  0.792772   1073.251  Kecimen

# %%
df.Class.unique()
# Out:
# <StringArray>
# ['Kecimen', 'Besni']
# Length: 2, dtype: str

# %%
sns.pairplot(data=df, hue='Class')

# %% [markdown]
# # 2. Preprocessing

# %%
df_features = df.select_dtypes(include='number')
df_target = df['Class']

# %%
x = StandardScaler().fit_transform(df_features)
y = LabelBinarizer().fit_transform(df_target)

# %%
x = pd.DataFrame(x, columns=df_features.columns)
x.head()
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0 -0.007186         0.097577        -0.023958      0.423142   -0.015709
# 1 -0.324217        -0.209012        -0.229292      0.224476   -0.304248
# 2  0.078292         0.097758         0.236988      0.186239    0.062113
# 3 -1.074286        -1.245051        -0.915273     -1.069623   -1.076165
# 4 -0.215393        -0.678958         0.727354     -2.409827   -0.238623
#
#      Extent  Perimeter
# 0  1.106743   0.066274
# 1 -0.287777  -0.161252
# 2 -1.158250   0.155945
# 3  0.001711  -1.175915
# 4  1.745259  -0.338639

# %%
y = pd.DataFrame(y, columns=['Class'])
y.head()
# Out:
#    Class
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
x.isna().sum()
y.isna().sum()
# Out:
# Class    0
# dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# # 3. The model

# %%
model = SVC(C=100, kernel='poly', degree=3)
model.fit(x_train, y_train)
model.score(x_test, y_test)
# Out:
# /home/fallou/mlpro/module_3/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8277777777777777

# %%
params = [
    {
        "kernel": ["linear"],
        "C": [1, 10, 20, 100],
        
    },
    {
        "kernel": ["rbf"],
        "C": [10, 20, 100],
    },
    {
        "kernel": ["poly"],
        "C": [1, 10, 20, 100],
        "degree": [2, 3]
    },
    {
        "kernel": ["sigmoid"],
        "C": [1, 10, 20, 100],
        "degree": [2, 3]
    }
]

# %%
model = GridSearchCV(estimator=SVC(),
                    param_grid=params,
                    cv=5)
model.fit(x_train, y_train)
# Out:
# /home/fallou/mlpro/module_3/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/fallou/mlpro/module_3/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/fallou/mlpro/module_3/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
model.best_params_
# Out:
# {'C': 1, 'kernel': 'linear'}

# %%
df[['MajorAxisLength', 'MinorAxisLength']]
# Out:
#      MajorAxisLength  MinorAxisLength
# 0         442.246011       253.291155
# 1         406.690687       243.032436
# 2         442.267048       266.328318
# 3         286.540559       208.760042
# 4         352.190770       290.827533
# ..               ...              ...
# 895       430.077308       247.838695
# 896       440.735698       259.293149
# 897       431.706981       298.837323
# 898       476.344094       254.176054
# 899       512.081774       215.271976
#
# [900 rows x 2 columns]
